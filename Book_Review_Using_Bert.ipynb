# %%
# !pip install tensorflow tensorflow-gpu pandas matplotlib sklearn
# Out:
# ...
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install torch==1.9.1+cu111 torchvision==0.10.1+cu111 torchaudio===0.9.1 -f https://download.pytorch.org/whl/cu111/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/cu111/torch_stable.html
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f635bd5e3e0>: Failed to establish a new connection: [Errno -2] Name or service not known')': /whl/cu111/torch_stable.html
# ERROR: Could not find a version that satisfies the requirement torch==1.9.1+cu111 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0)
# ERROR: No matching distribution found for torch==1.9.1+cu111

# %%
# !pip install transformers requests beautifulsoup4 pandas numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import requests
from bs4 import BeautifulSoup
import re
import numpy as np
import pandas as pd

# %%
tokenizer = AutoTokenizer.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')

model = AutoModelForSequenceClassification.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')

# %%
df = pd.read_csv('Book_Ratings_project.csv')

# %%
df.head()
# Out:
#                           profileName  \
# 0               Jim of Oz "jim-of-oz"
# 1                       Kevin Killian
# 2                        John Granger
# 3  Roy E. Perry "amateur philosopher"
# 4     D. H. Richards "ninthwavestore"
#
#                                     review/summary  review/score
# 0           Nice collection of Julie Strain images           4.0
# 1                                Really Enjoyed It           5.0
# 2  Essential for every personal and Public Library           5.0
# 3  Phlip Nel gives silly Seuss a serious treatment           4.0
# 4                           Good academic overview           4.0

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# alabaster                     0.7.13
# albumentations                1.2.1
# altair                        4.2.2
# anyio                         3.6.2
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.15.1
# astropy                       5.2.2
# astunparse                    1.6.3
# attrs                         23.1.0
# audioread                     3.0.0
# autograd                      1.5
# Babel                         2.12.1
# backcall                      0.2.0
# beautifulsoup4                4.11.2
# bleach                        6.0.0
# blis                          0.7.9
# blosc2                        2.0.0
# bokeh                         2.4.3
# branca                        0.6.0
# CacheControl                  0.12.11
# ...

# %%
# assuming the customer reviews are stored in a column called 'review' in a dataframe called 'df'
reviews = df['review/summary'].tolist()

# create an empty list to store the predictions
predictions = []

# loop through each review, encode it using the tokenizer, make a prediction using the pre-trained model, and store the predicted rating
for review in reviews:

  # encode the review using the tokenizer
  tokens = tokenizer.encode(review, return_tensors='pt')
    
  # make a prediction using the pre-trained model
  result = model(tokens)
    
  # extract the predicted rating from the logits and store it in the predictions list
  predicted_rating = int(torch.argmax(result.logits))+1
  predictions.append(predicted_rating)

# add the predictions to the dataframe as a new column
df['predicted_rating'] = predictions

# %%
df
# Out:
#                              profileName  \
# 0                  Jim of Oz "jim-of-oz"
# 1                          Kevin Killian
# 2                           John Granger
# 3     Roy E. Perry "amateur philosopher"
# 4        D. H. Richards "ninthwavestore"
# ...                                  ...
# 9995                      Mary Ann Payne
# 9996         Jay E. Schwartz "livediver"
# 9997                         A. Gorozdos
# 9998                          G'town mom
# 9999                                 Ron
#
#                                        review/summary  review/score  \
# 0              Nice collection of Julie Strain images           4.0
# 1                                   Really Enjoyed It           5.0
# 2     Essential for every personal and Public Library           5.0
# 3     Phlip Nel gives silly Seuss a serious treatment           4.0
# 4                              Good academic overview           4.0
# ...

# %%
df['predicted_rating'] = df['predicted_rating'].astype(float)
